# %% [markdown]
# # Fall Detection System - Research Demonstration
#
# **DISCLAIMER: This is a research demonstration only - NOT FOR CLINICAL USE**
#
# This notebook demonstrates the fall detection system using synthetic IMU sensor data.
#
# ## Overview
#
# The system analyzes accelerometer and gyroscope readings to classify activities as "fall" or "normal" using various machine learning approaches.
#
# ## Important Notes
#
# - This uses synthetic data only
# - Performance metrics are for demonstration purposes
# - Real-world performance may differ significantly
# - Always consult healthcare professionals for medical decisions

# %%
# Import required libraries
import sys
import os
sys.path.append(os.path.join(os.getcwd(), "src"))

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

from fall_detection.data import FallDetectionDataset
from fall_detection.models import RandomForestFallDetector
from fall_detection.metrics import FallDetectionMetrics
from fall_detection.utils import set_seed

# Set random seed for reproducibility
set_seed(42)

print("Libraries imported successfully!")
